# %% [markdown]
# # HANBAI

# %% [markdown]
# ## 1. Authentication

# %%
# !make hanbai-auth

# %% [markdown]
# ## 2. Push code

# %%
# !make commit "update"

# %% [markdown]
# ## 3. Generate test

# %%
# !make gen https://demo.hanbai.vn/login

# %% [markdown]
# ## 4. Test

# %% [markdown]
# ### 4.1 Menu

# %%
# !make start hanbai/test_menu.py
